# %% [markdown]
# <a href="https://colab.research.google.com/github/OhJunYoung21/artificial-inteliigence/blob/main/4%EC%9E%A5_%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%91%9C%ED%98%84%EA%B3%BC_%ED%8A%B9%EC%84%B1%EA%B3%B5%ED%95%99ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv('adult.csv',header=None,index_col=False,names = ['age','workclass','data_if_birth','education','education_num','married','occupation','relationship','gender','capital_gain','capital_loss',
                                                                 'hrs_of_work','native_country','income'])

data = data[['age','education','gender','hrs_of_work','occupation','income']]

data.head()


print(data.gender.value_counts())  #value_counts()라는 함수를 사용해서 범주를 간단하게 확인 할수 있었다.
# Out:
#  White                 27816
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: gender, dtype: int64
